# %% [markdown]
# # Main Heading
# ## Sub Heading
# ### Small Heading
#
# this is regular text
#
# ---
# draws line
#
# - Task list 1
# - Task list 2
#
# Shift + Enter - execute and move to next cell
#
# ctrl + Enter - Execute and remain in the same cell

# %% [markdown]
# Click b for adding plain text cell below and a for plain text above the current cell.
# Also then m for markdown and y for code

# %%
print("Hello Abhidha")
# Out:
# Hello Abhidha

# %% [markdown]
# So esc + arrow key to move up down cell in a quick way
# To delete a cell - double click dd.
#
# cell + y + enter --> makes python cell
# cell+ m + enter --> makes markdown cell

# %% [markdown]
# Good Habit - First import packages then use their functions
# Top to Bottom for scripting languages
